# %%
# !pip install nba_api
# Out:
# ...
# WARNING: You are using pip version 20.0.2; however, version 20.1.1 is available.
# You should consider upgrading via the 'c:\users\sagnik bakshi\appdata\local\programs\python\python38-32\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dict_ = {'a':[11,21,31], 'b':[12,22,32]}

# %%
df = pd.DataFrame(dict_)

# %%
df
# Out:
#     a   b
# 0  11  12
# 1  21  22
# 2  31  32

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#     a   b
# 0  11  12
# 1  21  22
# 2  31  32

# %%
df.mean()
# Out:
# a    21.0
# b    22.0
# dtype: float64

# %%
from nba_api.stats.static import teams

# %%
nba_teams = teams.get_teams()

# %%
nba_teams
# Out:
# [{'id': 1610612737,
#   'full_name': 'Atlanta Hawks',
#   'abbreviation': 'ATL',
#   'nickname': 'Hawks',
#   'city': 'Atlanta',
#   'state': 'Atlanta',
#   'year_founded': 1949},
#  {'id': 1610612738,
#   'full_name': 'Boston Celtics',
#   'abbreviation': 'BOS',
#   'nickname': 'Celtics',
#   'city': 'Boston',
#   'state': 'Massachusetts',
#   'year_founded': 1946},
#  {'id': 1610612739,
#   'full_name': 'Cleveland Cavaliers',
#   'abbreviation': 'CLE',
#   'nickname': 'Cavaliers',
#   'city': 'Cleveland',
#   'state': 'Ohio',
#   'year_founded': 1970},
#  {'id': 1610612740,
#   'full_name': 'New Orleans Pelicans',
#   'abbreviation': 'NOP',
#   'nickname': 'Pelicans',
#   'city': 'New Orleans',
#   'state': 'Louisiana',
#   'year_founded': 2002},
#  {'id': 1610612741,
#   'full_name': 'Chicago Bulls',
#   'abbreviation': 'CHI',
#   'nickname': 'Bulls',
#   'city': 'Chicago',
#   'state': 'Illinois',
#   'year_founded': 1966},
#  {'id': 1610612742,
# ...

# %%
nba_teams_df = pd.DataFrame(nba_teams)
nba_teams_df
# Out:
#             id               full_name abbreviation       nickname  \
# 0   1610612737           Atlanta Hawks          ATL          Hawks
# 1   1610612738          Boston Celtics          BOS        Celtics
# 2   1610612739     Cleveland Cavaliers          CLE      Cavaliers
# 3   1610612740    New Orleans Pelicans          NOP       Pelicans
# 4   1610612741           Chicago Bulls          CHI          Bulls
# 5   1610612742        Dallas Mavericks          DAL      Mavericks
# 6   1610612743          Denver Nuggets          DEN        Nuggets
# 7   1610612744   Golden State Warriors          GSW       Warriors
# 8   1610612745         Houston Rockets          HOU        Rockets
# 9   1610612746    Los Angeles Clippers          LAC       Clippers
# 10  1610612747      Los Angeles Lakers          LAL         Lakers
# 11  1610612748              Miami Heat          MIA           Heat
# 12  1610612749         Milwaukee Bucks          MIL          Bucks
# ...

# %%
def one_dict(list_dict):
    keys=list_dict[0].keys()
    out_dict={key:[] for key in keys}
    for dict_ in list_dict:
        for key, value in dict_.items():
            out_dict[key].append(value)
    return out_dict

# %%
dict_nba_team=one_dict(nba_teams)

# %%
teams_df = pd.DataFrame(dict_nba_team)
teams_df
# Out:
#             id               full_name abbreviation       nickname  \
# 0   1610612737           Atlanta Hawks          ATL          Hawks
# 1   1610612738          Boston Celtics          BOS        Celtics
# 2   1610612739     Cleveland Cavaliers          CLE      Cavaliers
# 3   1610612740    New Orleans Pelicans          NOP       Pelicans
# 4   1610612741           Chicago Bulls          CHI          Bulls
# 5   1610612742        Dallas Mavericks          DAL      Mavericks
# 6   1610612743          Denver Nuggets          DEN        Nuggets
# 7   1610612744   Golden State Warriors          GSW       Warriors
# 8   1610612745         Houston Rockets          HOU        Rockets
# 9   1610612746    Los Angeles Clippers          LAC       Clippers
# 10  1610612747      Los Angeles Lakers          LAL         Lakers
# 11  1610612748              Miami Heat          MIA           Heat
# 12  1610612749         Milwaukee Bucks          MIL          Bucks
# ...

# %%
df_rockets = nba_teams_df[nba_teams_df['nickname'] == 'Rockets']
df_rockets
# Out:
#            id        full_name abbreviation nickname     city  state  \
# 8  1610612745  Houston Rockets          HOU  Rockets  Houston  Texas
#
#    year_founded
# 8          1967

# %%
nba_teams_df['id']
# Out:
# 0     1610612737
# 1     1610612738
# 2     1610612739
# 3     1610612740
# 4     1610612741
# 5     1610612742
# 6     1610612743
# 7     1610612744
# 8     1610612745
# 9     1610612746
# 10    1610612747
# 11    1610612748
# 12    1610612749
# 13    1610612750
# 14    1610612751
# 15    1610612752
# 16    1610612753
# 17    1610612754
# 18    1610612755
# 19    1610612756
# 20    1610612757
# 21    1610612758
# 22    1610612759
# 23    1610612760
# 24    1610612761
# 25    1610612762
# 26    1610612763
# 27    1610612764
# 28    1610612765
# 29    1610612766
# Name: id, dtype: int64

# %%
from nba_api.stats.endpoints import leaguegamefinder

# %%
df_warriors
# Out:
#            id              full_name abbreviation  nickname          city  \
# 7  1610612744  Golden State Warriors          GSW  Warriors  Golden State
#
#         state  year_founded
# 7  California          1946

# %%
id_rockets = df_rockets['id']

# %%
id_rockets
# Out:
# 8    1610612745
# Name: id, dtype: int64

# %%
gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=id_rockets)

# %%
gamefinder.get_data_frames()
# Out:
# [     SEASON_ID     TEAM_ID TEAM_ABBREVIATION        TEAM_NAME     GAME_ID  \
#  0        22019  1610612745               HOU  Houston Rockets  0021900963
#  1        22019  1610612745               HOU  Houston Rockets  0021900953
#  2        22019  1610612745               HOU  Houston Rockets  0021900940
#  3        22019  1610612745               HOU  Houston Rockets  0021900927
#  4        22019  1610612745               HOU  Houston Rockets  0021900903
#  ...        ...         ...               ...              ...         ...
#  3384     21983  1610612745               HOU  Houston Rockets  0028300055
#  3385     21983  1610612745               HOU  Houston Rockets  0028300045
#  3386     21983  1610612745               HOU  Houston Rockets  0028300031
#  3387     21983  1610612745               HOU  Houston Rockets  0028300023
#  3388     21983  1610612745               HOU  Houston Rockets  0028300015
#
# ...

# %%
games = gamefinder.get_data_frames()[0]

# %%
games.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION        TEAM_NAME     GAME_ID  \
# 0     22019  1610612745               HOU  Houston Rockets  0021900963
# 1     22019  1610612745               HOU  Houston Rockets  0021900953
# 2     22019  1610612745               HOU  Houston Rockets  0021900940
# 3     22019  1610612745               HOU  Houston Rockets  0021900927
# 4     22019  1610612745               HOU  Houston Rockets  0021900903
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 0  2020-03-10  HOU vs. MIN  W  241  117  ...   0.769     5    28   33   24
# 1  2020-03-08  HOU vs. ORL  L  241  106  ...   0.760    11    27   38   21
# 2  2020-03-07    HOU @ CHA  L  239   99  ...   0.700    13    29   42   22
# 3  2020-03-05  HOU vs. LAC  L  240  105  ...   0.778    15    36   51   19
# 4  2020-03-02    HOU @ NYK  L  240  123  ...   0.926     8    26   34   25
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# 0    9    5   16  20         6.0
# ...

# %%
games
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION        TEAM_NAME     GAME_ID  \
# 0        22019  1610612745               HOU  Houston Rockets  0021900963
# 1        22019  1610612745               HOU  Houston Rockets  0021900953
# 2        22019  1610612745               HOU  Houston Rockets  0021900940
# 3        22019  1610612745               HOU  Houston Rockets  0021900927
# 4        22019  1610612745               HOU  Houston Rockets  0021900903
# ...        ...         ...               ...              ...         ...
# 3384     21983  1610612745               HOU  Houston Rockets  0028300055
# 3385     21983  1610612745               HOU  Houston Rockets  0028300045
# 3386     21983  1610612745               HOU  Houston Rockets  0028300031
# 3387     21983  1610612745               HOU  Houston Rockets  0028300023
# 3388     21983  1610612745               HOU  Houston Rockets  0028300015
#
#        GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# ...

# %%
# !pip install wget
# Out:
# ...
# WARNING: You are using pip version 20.0.2; however, version 20.1.1 is available.
# You should consider upgrading via the 'c:\users\sagnik bakshi\appdata\local\programs\python\python38-32\python.exe -m pip install --upgrade pip' command.
#     Running setup.py install for wget: started
#     Running setup.py install for wget: finished with status 'done'
# ...

# %%
wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%205/Labs/Golden_State.pkl
# Out:
#   File "<ipython-input-55-8c5045d91f0b>", line 1
#     wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%205/Labs/Golden_State.pkl
#          ^
# SyntaxError: invalid syntax

# %%
games
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION        TEAM_NAME     GAME_ID  \
# 0        22019  1610612745               HOU  Houston Rockets  0021900963
# 1        22019  1610612745               HOU  Houston Rockets  0021900953
# 2        22019  1610612745               HOU  Houston Rockets  0021900940
# 3        22019  1610612745               HOU  Houston Rockets  0021900927
# 4        22019  1610612745               HOU  Houston Rockets  0021900903
# ...        ...         ...               ...              ...         ...
# 3384     21983  1610612745               HOU  Houston Rockets  0028300055
# 3385     21983  1610612745               HOU  Houston Rockets  0028300045
# 3386     21983  1610612745               HOU  Houston Rockets  0028300031
# 3387     21983  1610612745               HOU  Houston Rockets  0028300023
# 3388     21983  1610612745               HOU  Houston Rockets  0028300015
#
#        GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# ...

# %%
games_home = games[games['MATCHUP'] == 'HOU vs. TOR']
games_home
games_away = games[games['MATCHUP'] == 'HOU @ TOR']
games_away
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION        TEAM_NAME     GAME_ID  \
# 43       22019  1610612745               HOU  Houston Rockets  0021900318
# 67       12019  1610612745               HOU  Houston Rockets  0011900017
# 104      22018  1610612745               HOU  Houston Rockets  0021800961
# 212      22017  1610612745               HOU  Houston Rockets  0021700979
# 341      22016  1610612745               HOU  Houston Rockets  0021600563
# 416      22015  1610612745               HOU  Houston Rockets  0021500936
# 517      22014  1610612745               HOU  Houston Rockets  0021401104
# 626      22013  1610612745               HOU  Houston Rockets  0021301118
# 777      22012  1610612745               HOU  Houston Rockets  0021200346
# 811      22012  1610612745               HOU  Houston Rockets  1521200002
# 838      22011  1610612745               HOU  Houston Rockets  0021100569
# 950      22010  1610612745               HOU  Houston Rockets  0021000173
# ...

# %%
games_home['PLUS_MINUS']
games_away['PLUS_MINUS']
# Out:
# 43      10.0
# 67      -5.0
# 104     12.0
# 212     -3.0
# 341      7.0
# 416      6.0
# 517     -3.0
# 626     -4.0
# 777     -7.0
# 811     12.0
# 838    -18.0
# 950    -10.0
# 971     -9.0
# 1034   -13.0
# 1060    12.0
# 1131   -21.0
# 1244   -13.0
# 1299    14.0
# 1423   -20.0
# 1548    -7.0
# 1630    -4.0
# 1662     2.0
# 1767    -6.0
# 1853    19.0
# 1903    -2.0
# 2081    24.0
# 2191   -11.0
# 2292     NaN
# Name: PLUS_MINUS, dtype: float64

# %%
games_home['PLUS_MINUS'].mean()
# Out:
# 5.961538461538462

# %%
games_home.mean()['PLUS_MINUS']
# Out:
# 5.961538461538462

# %%
games_away['PLUS_MINUS'].mean()
# Out:
# -1.4074074074074074

# %%
fig, ax = plt.subplots()
games_home.plot(x='GAME_DATE',y='PLUS_MINUS', ax=ax)
games_away.plot(x='GAME_DATE',y='PLUS_MINUS', ax=ax)
ax.legend(["home", "away"])
plt.show()
